# %%
import grafiti as gf
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np
import squidpy as sq
from sklearn import metrics
import umap as umap_ext

import warnings
warnings.filterwarnings('ignore')

datadir= "/home/mezallj1/grafiti/data"

# %%
def umap(adata, encoding_key="X_grafiti",n_neighbors=20,max_iter=100, min_dist=0.5, metric="euclidean", scanpy=False, neighbors_key="grafiti_neighbors", embd_name="X_umap"):
    if not scanpy:
        ldm = umap_ext.UMAP(n_epochs=max_iter,
                        n_neighbors=n_neighbors,
                        min_dist=min_dist,
                        metric=metric)
        embd = ldm.fit_transform(adata.obsm[encoding_key])
        adata.obsm[embd_name] = embd
    else:
        sc.tl.umap(adata,neighbors_key=neighbors_key)

# %%
adata = sc.read_h5ad(f'{datadir}/osmfish_remove_excluded.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 4839 × 33
#     obs: 'ClusterName', 'ClusterID', 'Region'
#     uns: 'ClusterName_colors'
#     obsm: 'spatial'

# %%
plot_data = adata.to_df()
features = ['Gad2', 'Slc32a1', 'Crhbp', 'Cnr1', 'Vip', 'Cpne5', 'Pthlh', 'Crh',
       'Tbr1', 'Lamp5', 'Rorb', 'Syt6', 'Kcnip2', 'Aldoc', 'Gfap', 'Serpinf1',
       'Mfge8', 'Sox10', 'Plp1', 'Pdgfra', 'Bmp4', 'Itpr2', 'Tmem2', 'Ctps',
       'Anln', 'Mrc1', 'Hexb', 'Ttr', 'Foxj1', 'Vtn', 'Flt1', 'Apln', 'Acta2']

# %%
fig, axes = plt.subplots(nrows=len(features), figsize=(5, 10))

for f, ax in zip(features, axes):
    #ax.set_xscale('log')
    ax.hist(plot_data[f], bins=np.linspace(0,2000,100))#, bins=np.logspace(np.log10(1.0), np.log10(10000.0), 50))
    ax.set_ylabel(f, rotation=0, ha='right', va='center')

plt.tight_layout()
# Out:
# /tmp/ipykernel_3351785/3580000630.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
sq.gr.spatial_neighbors(adata,radius=50,coord_type='generic',delaunay=True) # Creates spatial_connectivities and spatial_distances in 'obsp' from spatial location (x,y) in 'obsm'

# %%
gae = gf.ml.GAE(adata, layers=[50,50], lr=0.05)#, exponent=2, distance_scale=10)
# Out:
# Generating PyTorch Geometric Dataset...
# Setting up Model...
# Ready to train!

# %%
gae.train(10000, update_interval=100, threshold=1e-3)
# Out:
# Epoch 10000 ** iteration 0 ** Loss: 54257.445546875
# Epoch 10100 ** iteration 100 ** Loss: 54136.4763671875
# Epoch 10200 ** iteration 200 ** Loss: 54111.6823046875
# Epoch 10300 ** iteration 300 ** Loss: 54059.4624609375
# Epoch 10400 ** iteration 400 ** Loss: 54005.0670703125
# Epoch 10500 ** iteration 500 ** Loss: 53974.7359765625
# Epoch 10600 ** iteration 600 ** Loss: 53915.2437890625
# Epoch 10700 ** iteration 700 ** Loss: 54009.331953125
# Epoch 10800 ** iteration 800 ** Loss: 53826.734765625
# Epoch 10900 ** iteration 900 ** Loss: 53778.7603515625
# Epoch 11000 ** iteration 1000 ** Loss: 53724.924609375
# Epoch 11100 ** iteration 1100 ** Loss: 53705.6811328125
# Epoch 16200 ** iteration 6200 ** Loss: 51399.2777734375
# Epoch 16300 ** iteration 6300 ** Loss: 51363.58421875
# Epoch 16400 ** iteration 6400 ** Loss: 51364.666875
# Epoch 16500 ** iteration 6500 ** Loss: 51270.2388671875
# Epoch 16600 ** iteration 6600 ** Loss: 51239.625390625
# Epoch 16700 ** iteration 6700 ** Loss: 51335.0596875
# Epoch 16800 ** iteration 6800 ** Loss: 51151.7294921875
# Epoch 16900 ** iteration 6900 ** Loss: 51121.668046875
# Epoch 17000 ** iteration 7000 ** Loss: 51187.3283984375
# Epoch 17100 ** iteration 7100 ** Loss: 51037.6825390625
# Epoch 17200 ** iteration 7200 ** Loss: 51024.367578125
# Epoch 17300 ** iteration 7300 ** Loss: 50973.134921875
# Epoch 17400 ** iteration 7400 ** Loss: 50977.5391796875
# Epoch 17500 ** iteration 7500 ** Loss: 50989.3692578125
# Epoch 17600 ** iteration 7600 ** Loss: 50898.5212109375
# Epoch 17700 ** iteration 7700 ** Loss: 50825.13453125
# Epoch 17800 ** iteration 7800 ** Loss: 50846.5171484375
# Epoch 17900 ** iteration 7900 ** Loss: 50764.57875
# Epoch 18000 ** iteration 8000 ** Loss: 50801.2442578125
# Epoch 18100 ** iteration 8100 ** Loss: 50689.9245703125
# Epoch 18200 ** iteration 8200 ** Loss: 50671.4600390625
# Epoch 18300 ** iteration 8300 ** Loss: 50643.8437890625
# Epoch 18400 ** iteration 8400 ** Loss: 50870.7337890625
# Epoch 18500 ** iteration 8500 ** Loss: 50566.5387109375
# Epoch 18600 ** iteration 8600 ** Loss: 50539.23609375
# Epoch 18700 ** iteration 8700 ** Loss: 50503.5451171875
# Epoch 18800 ** iteration 8800 ** Loss: 51116.3378125
# Epoch 18900 ** iteration 8900 ** Loss: 50441.611953125
# Epoch 19000 ** iteration 9000 ** Loss: 50414.1286328125
# Epoch 19100 ** iteration 9100 ** Loss: 50453.5382421875
# Epoch 19200 ** iteration 9200 ** Loss: 50370.910703125
# Epoch 19300 ** iteration 9300 ** Loss: 50431.2606640625
# Epoch 19400 ** iteration 9400 ** Loss: 50292.388046875
# Epoch 19500 ** iteration 9500 ** Loss: 50299.83609375
# Epoch 19600 ** iteration 9600 ** Loss: 50237.45234375
# Epoch 19700 ** iteration 9700 ** Loss: 50206.1059765625
# Epoch 19800 ** iteration 9800 ** Loss: 50323.8586328125
# Epoch 19900 ** iteration 9900 ** Loss: 50273.1009375
# Complete.

# %%
gae.load_embedding(adata, encoding_key="X_grafiti") # Load features into the z latent space

# %%
gf.tl.umap(adata) # Embed grafiti latent space into umap latent space (2 dimensions)

# %%
gf.tl.find_motifs_gmm(adata,k=11)
# Out:
# Initialization 0
#   Iteration 10
#   Iteration 20
#   Iteration 30
#   Iteration 40
#   Iteration 50
#   Iteration 60
#   Iteration 70
# Initialization converged: True
# GaussianMixture(covariance_type='spherical', n_components=11, random_state=0,
#                 verbose=True)

# %% [markdown]
# # Leiden

# %%
adata_leiden = adata.copy()

# %%
n_clusters=11    #according own dataset

# %%
sc.tl.pca(adata_leiden, n_comps=50, svd_solver='arpack')
sc.pp.neighbors(adata_leiden, n_neighbors=100, n_pcs=50) # 20
eval_resolution = 2
sc.tl.leiden(adata_leiden, key_added="leiden", resolution=eval_resolution)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 sc.tl.pca(adata_leiden, n_comps=50, svd_solver='arpack')
#       2 sc.pp.neighbors(adata_leiden, n_neighbors=100, n_pcs=50) # 20
#       3 eval_resolution = 2
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:188, in pca(data, n_comps, zero_center, svd_solver, random_state, return_info, use_highly_variable, dtype, copy, chunked, chunk_size)
#     184         X = X.toarray()
#     185     pca_ = PCA(
#     186         n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     187     )
# --> 188     X_pca = pca_.fit_transform(X)
#     189 elif issparse(X) and zero_center:
#     190     from sklearn.decomposition import PCA
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:460, in PCA.fit_transform(self, X, y)
#     437 @_fit_context(prefer_skip_nested_validation=True)
#     438 def fit_transform(self, X, y=None):
#     439     """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441     Parameters
#    (...)
#     458     C-ordered array, use 'np.ascontiguousarray'.
#     459     """
# --> 460     U, S, Vt = self._fit(X)
#     461     U = U[:, : self.n_components_]
#     463     if self.whiten:
#     464         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:512, in PCA._fit(self, X)
#     510     return self._fit_full(X, n_components)
#     511 elif self._fit_svd_solver in ["arpack", "randomized"]:
# --> 512     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/miniconda3/envs/macklowe/lib/python3.9/site-packages/sklearn/decomposition/_pca.py:585, in PCA._fit_truncated(self, X, n_components, svd_solver)
#     580     raise ValueError(
#     581         "n_components=%r cannot be a string with svd_solver='%s'"
#     582         % (n_components, svd_solver)
#     583     )
#     584 elif not 1 <= n_components <= min(n_samples, n_features):
# --> 585     raise ValueError(
#     586         "n_components=%r must be between 1 and "
#     587         "min(n_samples, n_features)=%r with "
#     588         "svd_solver='%s'"
#     589         % (n_components, min(n_samples, n_features), svd_solver)
#     590     )
#     591 elif svd_solver == "arpack" and n_components == min(n_samples, n_features):
#     592     raise ValueError(
#     593         "n_components=%r must be strictly less than "
#     594         "min(n_samples, n_features)=%r with "
#     595         "svd_solver='%s'"
#     596         % (n_components, min(n_samples, n_features), svd_solver)
#     597     )
#
# ValueError: n_components=50 must be between 1 and min(n_samples, n_features)=33 with svd_solver='arpack'

# %%
sc.pl.embedding(adata_leiden, basis='spatial', color ='leiden', s=20, add_outline=True)
# Out:
# /home/mezallj1/miniconda3/envs/macklowe/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:371: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# /home/mezallj1/miniconda3/envs/macklowe/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:381: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# /home/mezallj1/miniconda3/envs/macklowe/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # GraphST

# %%
adata_graphst = sc.read_h5ad(f'{datadir}/osmfish_graphst.h5ad')

# %%
adata.obs['domain'] = adata_graphst.obs['domain']

# %%
adata_graphst
# Out:
# AnnData object with n_obs × n_vars = 4839 × 33
#     obs: 'ClusterName', 'ClusterID', 'Region', 'mclust', 'domain'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'ClusterName_colors', 'Region_colors', 'domain_colors', 'hvg', 'log1p'
#     obsm: 'adj', 'distance_matrix', 'emb', 'emb_pca', 'feat', 'feat_a', 'graph_neigh', 'label_CSL', 'spatial'

# %%
umap(adata_graphst, encoding_key="emb")

# %% [markdown]
# # Plots

# %%
# calculate metric ARI
graphst_ari = metrics.adjusted_rand_score(adata.obs['domain'], adata.obs['Region'])
grafiti_ari = metrics.adjusted_rand_score(adata.obs['grafiti_motif'], adata.obs['Region'])

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
sc.pl.embedding(adata, basis='spatial', title = 'Ground Truth', color='Region', ax=axes[0], s=20, add_outline=True, show=False)
sc.pl.embedding(adata, basis='spatial', title = 'GraphST: %.3f'%(graphst_ari), color ='domain', ax=axes[1], s=20, add_outline=True, show=False)
sc.pl.embedding(adata, basis='spatial', title = 'Grafiti: %.3f'%(grafiti_ari), color ='grafiti_motif', ax=axes[2], s=20, add_outline=True, show=False)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sc.pl.umap(adata_graphst,title="GraphST",color=["domain"],ax=axes[0],s=20,show=False)
sc.pl.umap(adata,title="Grafiti",color=["grafiti_motif"],ax=axes[1],s=20,show=False)
plt.tight_layout()
plt.show()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4839 × 33
#     obs: 'ClusterName', 'ClusterID', 'Region', 'grafiti_motif', 'GrafitiMotif0_proba', 'GrafitiMotif1_proba', 'GrafitiMotif10_proba', 'GrafitiMotif2_proba', 'GrafitiMotif3_proba', 'GrafitiMotif4_proba', 'GrafitiMotif5_proba', 'GrafitiMotif6_proba', 'GrafitiMotif7_proba', 'GrafitiMotif8_proba', 'GrafitiMotif9_proba', 'domain'
#     uns: 'ClusterName_colors', 'spatial_neighbors', 'grafiti_motif_proba', 'Region_colors', 'domain_colors', 'grafiti_motif_colors'
#     obsm: 'spatial', 'X_grafiti', 'X_umap'
#     obsp: 'spatial_connectivities', 'spatial_distances'
